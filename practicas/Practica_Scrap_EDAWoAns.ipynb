# %% [markdown]
# <a href="https://colab.research.google.com/github/fax117/machine_learning_practices/blob/main/practicas/Practica_Scrap_EDAWoAns.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/MauricioRR-Tec/AprendizajeAutomatico/blob/master/Tema_2_AnalisisEstadistico/notebook/exercises/Practica_Scrap_EDAWoAns.ipynb)

# %% [markdown]
# # ![LogoITESM2.png](data:image/png;base64,...)
#
# #Nombres:
# ### Fabricio Andre Fuetnes Fuentes A0133852
# ### José Sebastián Reyes López    A01655218
# ### Luis Carlos Ordoñez           A01653435
# ### Pamela Arias De la Luz A01655238

# %% [markdown]
# <h1><center>Práctica de Módulo 2</center><h1>

# %% [markdown]
# ## ¿Qué es web scrapping?
#
# Es una técnica para recuperar grandes cantidades de datos de Internet.
#
# -----
#
# Existen diferentes técnicas como Scrappy, BeautifulSoup, etc. La librería más común es BeautifulSoup.
#
# Extrae la página Html de cualquier sitio web. Los datos almacenados por web Scrapping son un formato no estructurado. Convertimos los datos no estructurados en estructurados para el análisis y la exploración de datos.
#
# ------
#
# ### Bibliotecas utilizadas para Web Scraping
#
# Como sabemos, Python se usa para varias aplicaciones y existen diferentes bibliotecas para diferentes propósitos. En nuestra demostración adicional, usaremos las siguientes bibliotecas:
#
#    * BeautifulSoup: Beautiful Soup es un paquete de Python para analizar documentos HTML y XML. Crea árboles de análisis que son útiles para extraer los datos fácilmente.
#    * Pandas: Pandas es una biblioteca que se utiliza para la manipulación y el análisis de datos. Se utiliza para extraer los datos y almacenarlos en el formato deseado.
#    * Utilice matplotlib y seaborn para la visualización de datos

# %% [markdown]
# ------
# ### ¿Cómo funciona el Web Scraping?
#
# Cuando ejecuta el código para web scraping, se envía una solicitud a la URL que ha mencionado. Como respuesta a la solicitud, el servidor envía los datos y le permite leer la página HTML o XML. Luego, el código analiza la página HTML o XML, encuentra los datos y los extrae.
#
# Para extraer datos utilizando web scraping con Python, debe seguir estos pasos básicos:
#
#    * Busque la URL que desea raspar
#    * Inspecciona la página
#    * Encuentra los datos que quieres extraer
#    * Escribe el codigo
#    * Ejecute el código y extraiga los datos
#    * Almacene los datos en el formato requerido
#
# ------

# %% [markdown]
# -------
#
# ### Datos del sitio web de Flipkart
#
# Para comprobar cuál debería ser el precio óptimo de nuestro producto, estos precios pueden variar mucho. Entonces, vamos a mostrar cómo podemos obtener información relacionada con un producto en particular (computadora portátil).
#
# Primero, importemos todas las bibliotecas necesarias:

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup

# %% [markdown]
# Los datos que extraemos son datos no estructurados. Por eso, crearemos listas vacías para almacenarlas de forma estructurada

# %%
name=[]
prices=[]
ratings=[]
df = pd.DataFrame()

# %% [markdown]
# ## Paso 1: busque la URL
#
# Para este ejemplo, vamos a **raspar** (Scrap) el sitio web de **Flipkart** para extraer el nombre, el precio y la calificación de las computadoras portátiles. La URL de esta página es:
#
# [Flipkart](https://www.flipkart.com/search?q=laptops&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&as-pos=1&as-type=HISTORY.)

# %%
url = "https://www.flipkart.com/search?q=laptops&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&as-pos=1&as-type=HISTORY"

# %%
response = requests.get(url)

# %%
response
# Out:
# <Response [200]>

# %% [markdown]
# ### Paso 2: inspección de la página
#
# Los datos suelen estar anidados en etiquetas. Entonces, inspeccionamos la página para ver, bajo qué etiqueta están anidados los datos que queremos raspar. Para inspeccionar la página, simplemente haga clic derecho en el elemento y haga clic en "Inspeccionar" (o F12).

# %% [markdown]
# ![img](https://miro.medium.com/max/571/0*TF2VBxPanqhxb-hY.png)

# %% [markdown]
# ### Paso 3: busque los datos que desea extraer
#
# Extraigamos el nombre, precio y calificación que están anidados en la etiqueta "div" respectivamente.
#
# Por lo general, nos confundiremos sobre qué etiqueta necesitamos copiar para esta computadora portátil. Podemos usar https://webformatter.com/ para filtrar la etiqueta por el nombre, el precio y la calificación, y podemos copiar fácilmente con esta herramienta.
#
# Ahora que hemos escrito el código para abrir la URL, es hora de extraer los datos del sitio web. Como se mencionó anteriormente, los datos que queremos extraer están anidados en etiquetas <div>. Entonces, encontraremos las etiquetas div con esos respectivos nombres de clase, extraeremos y almacenaremos los datos en una variable. Consulte el código a continuación:

# %%
soup = BeautifulSoup(response.text, 'html.parser')

# %%
main_box=soup.find_all("div", class_='_13oc-S')

# %%
len(main_box)
# Out:
# 24

# %%
box=main_box[1]

# %%
box
# Out:
# <div class="_13oc-S"><div data-id="COMFXU6P8VA5RYTG" style="width:100%"><div class="_2kHMtA"><div class="_2tfzpE"><span>Ad</span></div><a class="_1fQZEK" href="/asus-zenbook-flip-s-oled-core-i7-11th-gen-intel-evo-16-gb-1-tb-ssd-windows-10-home-ux371ea-hl701ts-thin-light-laptop/p/itm325dcc4b58bb7?pid=COMFXU6P8VA5RYTG&amp;lid=LSTCOMFXU6P8VA5RYTGKSMWR2&amp;marketplace=FLIPKART&amp;q=laptops&amp;store=6bo%2Fb5g&amp;srno=s_1_2&amp;otracker=search&amp;otracker1=search&amp;fm=organic&amp;iid=en_Lr6pHOtDHw%2BuVyA8z4s2DZdLCRfGjGYM1X7tpcw2qQQucwpYDby57SfxaLXmvR69%2FGjqGf1Rthevc%2BkcTzu%2FQg%3D%3D&amp;ppt=None&amp;ppn=None&amp;ssid=xrlp3emwao0000001631602520122&amp;qH=c06ea84a1e3dc3c6" rel="noopener noreferrer" target="_blank"><div class="MIXNux"><div class="_2QcLo-"><div><div class="CXW8mj" style="height:200px;width:200px"><img alt="ASUS ZenBook Flip S OLED Core i7 11th Gen Intel EVO - (16 GB/1 TB SSD/Windows 10 Home) UX371EA-HL701TS..." class="_396cs4 _3exPp9" src="https://rukminim1.flixcart.com/image/312/312/kr9jafk0/computer/r/g/f/na-thin-and-light-laptop-asus-original-imag539yjjhvjcsy.jpeg?q=70"/></div></div></div><div class="_3wLduG"><div class="_3PzNI-"><span class="f3A4_V"><label class="_2iDkf8"><input class="_30VH1S" readonly="" type="checkbox"/><div class="_24_Dny"></div></label></span><label class="_6Up2sF"><span>Add to Compare</span></label></div></div><div class="_2hVSre _3nq8ih"><div class="_36FSn5"><svg class="_1l0elc" height="16" viewbox="0 0 20 16" width="16" xmlns="http://www.w3.org/2000/svg"><path class="eX72wL" d="M8.695 16.682C4.06 12.382 1 9.536 1 6.065 1 3.219 3.178 1 5.95 1c1.566 0 3.069.746 4.05 1.915C10.981 1.745 12.484 1 14.05 1 16.822 1 19 3.22 19 6.065c0 3.471-3.06 6.316-7.695 10.617L10 17.897l-1.305-1.215z" fill="#2874F0" fill-rule="evenodd" opacity=".9" stroke="#FFF"></path></svg></div></div></div><div class="_3pLy-c row"><div class="col col-7-12"><div class="_4rR01T">ASUS ZenBook Flip S OLED Core i7 11th Gen Intel EVO - (16 GB/1 TB SSD/Windows 10 Home) UX371EA-HL701TS...</div><div class="gUuXy-"><span class="_1lRcqv" id="productRating_LSTCOMFXU6P8VA5RYTGKSMWR2_COMFXU6P8VA5RYTG_"><div class="_3LWZlK">4.2<img class="_1wB99o" src="..."/></div></span><span class="_2_R_DZ"><span><span>6 Ratings </span><span class="_13vcmD">&amp;</span><span> 0 Reviews</span></span></span></div><div class="fMghEO"><ul class="_1xgFaf"><li class="rgWa7D">Intel Evo platform feat 11th Gen Intel Core i7 processor</li><li class="rgWa7D">Intel Core i7 Processor (11th Gen)</li><li class="rgWa7D">16 GB LPDDR4X RAM</li><li class="rgWa7D">64 bit Windows 10 Operating System</li><li class="rgWa7D">1 TB SSD</li><li class="rgWa7D">33.78 cm (13.3 inch) Touchscreen Display</li><li class="rgWa7D">Microsoft Office Home and Student 2019, My Asus, Splendid, Tru2Life</li><li class="rgWa7D">1 Year Onsite Warranty</li></ul></div></div><div class="col col-5-12 nlI3QM"><div class="_3tbKJL"><div class="_25b18c"><div class="_30jeq3 _1_WHN1">₹1,49,990</div><div class="_3I9_wc _27UcVY">₹<!-- -->1,82,990</div><div class="_3Ay6Sb"><span>18% off</span></div></div></div><div class="_13J9qT"><img height="21" src="//static-assets-web.flixcart.com/www/linchpin/fk-cp-zion/img/fa_62673a.png"/></div><div class="_2ZdXDB"><div class="_3xFhiH"><div class="_2Tpdn3 _18hQoS" style="color:#000000;font-size:12px;font-style:normal;font-weight:400">No Cost EMI from ₹24,999/month</div></div></div></div></div></a></div></div></div>

# %%
title = box.find( 'div', class_="_4rR01T").text
rating = box.find('div', class_="_3LWZlK").text
price = box.find('div', class_="_30jeq3 _1_WHN1").text

# %%
print(title,price,rating)
# Out:
# ASUS ZenBook Flip S OLED Core i7 11th Gen Intel EVO - (16 GB/1 TB SSD/Windows 10 Home) UX371EA-HL701TS... ₹1,49,990 4.2

# %%
data_list=[]

for box in main_box:
    temp_dict={}
    temp_dict['title'] = box.find( 'div', class_="_4rR01T").text
    if box.find('div',class_='_3LWZlK')!=None:
      temp_dict['rating'] = float(box.find('div',class_='_3LWZlK').text)
    else:
      temp_dict['rating'] = 0.0
    temp_dict['price'] = int(box.find('div',class_='_30jeq3 _1_WHN1').text[1:].replace(',',""))
    data_list.append(temp_dict)

# %% [markdown]
# ### Paso 4: Crear un dataframe y guardar los datos en csv
#
# Después de extraer los datos, es posible que desee almacenarlos en un formato. Este formato varía según sus necesidades. Para este ejemplo, almacenaremos los datos extraídos en formato CSV (valores separados por comas). Para hacer esto, agregaré las siguientes líneas a mi código:

# %%
df = pd.DataFrame(data_list)

# %%
df
# Out:
#                                                 title  rating   price
# 0   DELL XPS Core i5 10th Gen - (8 GB/512 GB SSD/W...     0.0  119990
# 1   ALIENWARE Core i9 10th Gen - (32 GB/1 TB SSD/W...     4.6  319990
# 2   HP 14s Core i3 11th Gen - (8 GB/256 GB SSD/Win...     4.4   41990
# 3   HP Pavilion Ryzen 5 Hexa Core 5600H - (8 GB/51...     4.5   64056
# 4   acer Aspire 7 Ryzen 5 Hexa Core 5500U - (8 GB/...     4.5   56990
# 5   Lenovo IdeaPad Slim 3i (2021) Core i3 11th Gen...     4.4   45990
# 6   Lenovo APU Dual Core A9 A99425 - (4 GB/1 TB HD...     4.6   28000
# 7   ASUS VivoBook 15 Core i3 10th Gen - (4 GB/1 TB...     3.8   34990
# 8   acer Aspire 7 Core i5 10th Gen - (8 GB/512 GB ...     4.4   56990
# 9   HP Ryzen 5 Quad Core 3500U - (8 GB/1 TB HDD/25...     4.4   47990
# 10  HP 15s Ryzen 3 Dual Core 3250U - (8 GB/1 TB HD...     4.2   38499
# 11  DELL Inspiron 7000 Core i5 10th Gen - (8 GB/51...     0.0   69990
# 12  HP 15-ec1105AX Ryzen 5 Hexa Core 4600H - (8 GB...     4.5   59990
# 13  Lenovo IdeaPad 3 Core i3 10th Gen - (8 GB/1 TB...     4.3   39990
# 14  DELL Vostro Core i3 10th Gen - (4 GB/256 GB SS...     4.2   36057
# 15  DELL Vostro Core i3 10th Gen - (8 GB/1 TB HDD/...     4.0   37379
# 16  ASUS VivoBook Flip Ryzen 5 Hexa Core - (8 GB/5...     4.4   59990
# 17  ASUS TUF Gaming F15 Core i5 10th Gen - (8 GB/5...     4.5   61990
# 18  ASUS TUF Gaming A17 Ryzen 7 Octa Core 4800H - ...     4.6   88990
# 19  DELL Inspiron Ryzen 5 Quad Core 3450U - (8 GB/...     4.2   42890
# 20  Lenovo IdeaPad Core i3 10th Gen - (8 GB/256 GB...     4.2   39990
# 21  HP Pavilion Core i5 11th Gen - (16 GB/512 GB S...     4.5   66990
# 22  MSI GF65 Thin Hexa Core i5 10th Gen - (16 GB/5...     4.6   74990
# 23  Lenovo Core i5 9th Gen - (8 GB/1 TB HDD/Window...     4.1   49990

# %%
df.to_csv("datos_compus.csv", index=False, encoding='utf-8')

# %% [markdown]
# ### Paso 5: Un poco de EDA y visualización de este archivo

# %%
laptop_df = pd.read_csv("datos_compus.csv", sep=None, thousands=',', engine='python')

# %%
laptop_df
# Out:
#                                                 title  rating   price
# 0   DELL XPS Core i5 10th Gen - (8 GB/512 GB SSD/W...     0.0  119990
# 1   ALIENWARE Core i9 10th Gen - (32 GB/1 TB SSD/W...     4.6  319990
# 2   HP 14s Core i3 11th Gen - (8 GB/256 GB SSD/Win...     4.4   41990
# 3   HP Pavilion Ryzen 5 Hexa Core 5600H - (8 GB/51...     4.5   64056
# 4   acer Aspire 7 Ryzen 5 Hexa Core 5500U - (8 GB/...     4.5   56990
# 5   Lenovo IdeaPad Slim 3i (2021) Core i3 11th Gen...     4.4   45990
# 6   Lenovo APU Dual Core A9 A99425 - (4 GB/1 TB HD...     4.6   28000
# 7   ASUS VivoBook 15 Core i3 10th Gen - (4 GB/1 TB...     3.8   34990
# 8   acer Aspire 7 Core i5 10th Gen - (8 GB/512 GB ...     4.4   56990
# 9   HP Ryzen 5 Quad Core 3500U - (8 GB/1 TB HDD/25...     4.4   47990
# 10  HP 15s Ryzen 3 Dual Core 3250U - (8 GB/1 TB HD...     4.2   38499
# 11  DELL Inspiron 7000 Core i5 10th Gen - (8 GB/51...     0.0   69990
# 12  HP 15-ec1105AX Ryzen 5 Hexa Core 4600H - (8 GB...     4.5   59990
# 13  Lenovo IdeaPad 3 Core i3 10th Gen - (8 GB/1 TB...     4.3   39990
# 14  DELL Vostro Core i3 10th Gen - (4 GB/256 GB SS...     4.2   36057
# 15  DELL Vostro Core i3 10th Gen - (8 GB/1 TB HDD/...     4.0   37379
# 16  ASUS VivoBook Flip Ryzen 5 Hexa Core - (8 GB/5...     4.4   59990
# 17  ASUS TUF Gaming F15 Core i5 10th Gen - (8 GB/5...     4.5   61990
# 18  ASUS TUF Gaming A17 Ryzen 7 Octa Core 4800H - ...     4.6   88990
# 19  DELL Inspiron Ryzen 5 Quad Core 3450U - (8 GB/...     4.2   42890
# 20  Lenovo IdeaPad Core i3 10th Gen - (8 GB/256 GB...     4.2   39990
# 21  HP Pavilion Core i5 11th Gen - (16 GB/512 GB S...     4.5   66990
# 22  MSI GF65 Thin Hexa Core i5 10th Gen - (16 GB/5...     4.6   74990
# 23  Lenovo Core i5 9th Gen - (8 GB/1 TB HDD/Window...     4.1   49990

# %%
df.shape
# Out:
# (24, 3)

# %%
df.dtypes
# Out:
# title      object
# rating    float64
# price       int64
# dtype: object

# %% [markdown]
# Quiero dividir el título debido a todas las especificaciones y nombres de portátiles en una fila.
#
# Lo dividiremos en diferentes columnas por separado usando la opción split ()

# %%
laptop_df['model'], laptop_df['spec'] = laptop_df['title'].str.split('-', 1).str
del laptop_df['title']
laptop_df.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Columnar iteration over characters will be deprecated in future releases.
#   """Entry point for launching an IPython kernel.
#    rating  ...                                               spec
# 0     0.0  ...   (8 GB/512 GB SSD/Windows 10 Home) XPS 9300 Th...
# 1     4.6  ...   (32 GB/1 TB SSD/Windows 10 Home/8 GB Graphics...
# 2     4.4  ...   (8 GB/256 GB SSD/Windows 10 Home) 14s- DY2501...
# 3     4.5  ...   (8 GB/512 GB SSD/Windows 10 Home/4 GB Graphic...
# 4     4.5  ...   (8 GB/512 GB SSD/Windows 10 Home/4 GB Graphic...
#
# [5 rows x 4 columns]

# %% [markdown]
# Usamos esta opción dividida (split "-") para separar del título y crear una columna separada como modelo y especificación y eliminar el título

# %%
laptop_df['Extras'], laptop_df['spec']  = laptop_df['spec'].str.split('(',1).str
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Columnar iteration over characters will be deprecated in future releases.
#   """Entry point for launching an IPython kernel.

# %%
laptop_df['model'] = laptop_df['model'].str.cat(laptop_df['Extras'], sep=" ")
del laptop_df['Extras']

# %%
laptop_df.head()
# Out:
#    rating  ...                                               spec
# 0     0.0  ...  8 GB/512 GB SSD/Windows 10 Home) XPS 9300 Thin...
# 1     4.6  ...  32 GB/1 TB SSD/Windows 10 Home/8 GB Graphics/N...
# 2     4.4  ...  8 GB/256 GB SSD/Windows 10 Home) 14s- DY2501TU...
# 3     4.5  ...  8 GB/512 GB SSD/Windows 10 Home/4 GB Graphics/...
# 4     4.5  ...  8 GB/512 GB SSD/Windows 10 Home/4 GB Graphics/...
#
# [5 rows x 4 columns]

# %%
laptop_df.insert(3,"RAM",'')
laptop_df.head()
# Out:
#    rating   price  ... RAM                                               spec
# 0     0.0  119990  ...      8 GB/512 GB SSD/Windows 10 Home) XPS 9300 Thin...
# 1     4.6  319990  ...      32 GB/1 TB SSD/Windows 10 Home/8 GB Graphics/N...
# 2     4.4   41990  ...      8 GB/256 GB SSD/Windows 10 Home) 14s- DY2501TU...
# 3     4.5   64056  ...      8 GB/512 GB SSD/Windows 10 Home/4 GB Graphics/...
# 4     4.5   56990  ...      8 GB/512 GB SSD/Windows 10 Home/4 GB Graphics/...
#
# [5 rows x 5 columns]

# %%
laptop_df['RAM'], laptop_df['Storage'] = laptop_df['spec'].str.split('/',1).str
del laptop_df['spec']
laptop_df.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Columnar iteration over characters will be deprecated in future releases.
#   """Entry point for launching an IPython kernel.
#    rating   price  ...    RAM                                            Storage
# 0     0.0  119990  ...   8 GB  512 GB SSD/Windows 10 Home) XPS 9300 Thin and ...
# 1     4.6  319990  ...  32 GB  1 TB SSD/Windows 10 Home/8 GB Graphics/NVIDIA ...
# 2     4.4   41990  ...   8 GB  256 GB SSD/Windows 10 Home) 14s- DY2501TU Thin...
# 3     4.5   64056  ...   8 GB  512 GB SSD/Windows 10 Home/4 GB Graphics/NVIDI...
# 4     4.5   56990  ...   8 GB  512 GB SSD/Windows 10 Home/4 GB Graphics/NVIDI...
#
# [5 rows x 5 columns]

# %% [markdown]
# Continuemos hasta conseguir lo siguiente...

# %%
laptop_df['Storage'], laptop_df['OS'] = laptop_df['Storage'].str.split('/',1).str
laptop_df.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Columnar iteration over characters will be deprecated in future releases.
#   """Entry point for launching an IPython kernel.
#    rating  ...                                                 OS
# 0     0.0  ...    Windows 10 Home) XPS 9300 Thin and Light Laptop
# 1     4.6  ...  Windows 10 Home/8 GB Graphics/NVIDIA GeForce R...
# 2     4.4  ...  Windows 10 Home) 14s- DY2501TU Thin and Light ...
# 3     4.5  ...  Windows 10 Home/4 GB Graphics/NVIDIA GeForce G...
# 4     4.5  ...   Windows 10 Home/4 GB Graphics/NVIDIA GeForce ...
#
# [5 rows x 6 columns]

# %%
laptop_df['System'], laptop_df['Other_Info'] = laptop_df['OS'].str.split('[/)]',1).str
del laptop_df['OS']
laptop_df.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Columnar iteration over characters will be deprecated in future releases.
#   """Entry point for launching an IPython kernel.
#    rating  ...                                    Other_Info
# 0     0.0  ...                XPS 9300 Thin and Light Laptop
# 1     4.6  ...  8 GB Graphics/NVIDIA GeForce RTX 2080 wit...
# 2     4.4  ...           14s- DY2501TU Thin and Light Laptop
# 3     4.5  ...            4 GB Graphics/NVIDIA GeForce GT...
# 4     4.5  ...              4 GB Graphics/NVIDIA GeForce ...
#
# [5 rows x 7 columns]

# %% [markdown]
# ### Paso 6: Identificación de valores perdidos
#
# Los métodos isnull () y notnull () son las formas más comunes de identificar valores perdidos.
#
# Mientras maneja los datos faltantes, primero debe identificar las filas y columnas que contienen los valores faltantes, contar el número de valores faltantes y luego decidir cómo desea tratarlos.
#
# Es importante que trate los valores faltantes en cada columna por separado, en lugar de implementar una única solución (por ejemplo, reemplazar los NaN por la media de una columna) para todas las columnas.
#
# isnull () devuelve un valor booleano (Verdadero / Falso) que luego se puede usar para encontrar las filas o columnas que contienen valores perdidos.

# %%
laptop_df.isna()
# Out:
#     rating  price  model    RAM  Storage  System  Other_Info
# 0    False  False  False  False    False   False       False
# 1    False  False  False  False    False   False       False
# 2    False  False  False  False    False   False       False
# 3    False  False  False  False    False   False       False
# 4    False  False  False  False    False   False       False
# 5    False  False  False  False    False   False       False
# 6    False  False  False  False    False   False       False
# 7    False  False  False  False    False   False       False
# 8    False  False  False  False    False   False       False
# 9    False  False  False  False    False   False       False
# 10   False  False  False  False    False   False       False
# 11   False  False  False  False    False   False       False
# 12   False  False  False  False    False   False       False
# 13   False  False  False  False    False   False       False
# 14   False  False  False  False    False   False       False
# 15   False  False  False  False    False   False       False
# 16   False  False  False  False    False   False       False
# 17   False  False  False  False    False   False       False
# 18   False  False  False  False    False   False       False
# 19   False  False  False  False    False   False       False
# 20   False  False  False  False    False   False       False
# 21   False  False  False  False    False   False       False
# 22   False  False  False  False    False   False       False
# 23   False  False  False  False    False   False       False

# %% [markdown]
# ### Identificación de valores perdidos en columnas
#
# Primero calculemos el número total de valores faltantes en el marco de datos. Puede calcular el número de valores perdidos en cada columna mediante df.isnull().Sum()

# %%
laptop_df.isna().sum()
# Out:
# rating        0
# price         0
# model         0
# RAM           0
# Storage       0
# System        0
# Other_Info    0
# dtype: int64

# %%
#completa

# %%
laptop_df.groupby('model').size()
# Out:
# model
# ASUS Core i3 10th Gen                                          1
# ASUS VivoBook Ultra 15 Core i5 11th Gen                        1
# ASUS VivoBook Ultra K14 (2021) Core i3 11th Gen                1
# ASUS ZenBook Flip S OLED Core i7 11th Gen Intel EVO            1
# DELL Inspiron Core i5 11th Gen                                 1
# DELL Inspiron Ryzen 3 Dual Core 3250U                          1
# HP 14s Core i3 11th Gen                                        1
# HP 15 ec1105AX Ryzen 5 Hexa Core 4600H -                       1
# HP Core i3 10th Gen                                            1
# HP Pavilion Core i5 11th Gen                                   1
# HP Pavilion Ryzen 5 Hexa Core 5600H                            1
# HP Ryzen 5 Quad Core 3500U                                     1
# Lenovo APU Dual Core A9 A99425                                 1
# Lenovo IdeaPad 3 Core i3 10th Gen                              1
# Lenovo IdeaPad 3 Core i3 11th Gen                              1
# Lenovo IdeaPad Core i3 10th Gen                                1
# Lenovo IdeaPad Slim 3i (2021) Core i3 11th Gen                 1
# Lenovo Legion Core i5 9th Gen                                  1
# Lenovo ThinkPad E14 Gen2 Ryzen 5 Hexa Core 4650U 5th Gen       1
# Lenovo ThinkPad E15 Core i5 11th Gen                           1
# MSI Prestige 14 EVO Core i5 11th Gen                           1
# acer Aspire 7 Ryzen 5 Hexa Core 5500U                          1
# acer Swift 5 Core i7 11th Gen Intel EVO                        1
# lenovo Ideapad Slim 5i Core i5 11th Gen Intel EVO              1
# dtype: int64

# %%
laptop_df[["rating","price"]].describe()
# Out:
#           rating          price
# count  24.000000      24.000000
# mean    3.995833   66029.208333
# std     1.247425   57720.798170
# min     0.000000   28000.000000
# 25%     4.200000   39990.000000
# 50%     4.400000   53490.000000
# 75%     4.500000   64789.500000
# max     4.600000  319990.000000

# %%
laptop_df.dtypes
# Out:
# rating        float64
# price           int64
# model          object
# RAM            object
# Storage        object
# System         object
# Other_Info     object
# dtype: object

# %% [markdown]
# Ahora necesitamos filtrar las mejores computadoras portátiles con buenas especificaciones, precio y calificación de la lista

# %% [markdown]
# Muestra los siguientes resultados:
#  * Laptops en rating <= 4
#  * Laptops con rating >= 3.5 y un precio entre 30 y 40 mil $

# %%
laptop_df[laptop_df['rating']<=4]
# Out:
#     rating   price  ...           System                              Other_Info
# 0      0.0  119990  ...  Windows 10 Home          XPS 9300 Thin and Light Laptop
# 7      3.8   34990  ...  Windows 10 Home   X515JA-BR381T Thin and Light Lapto...
# 11     0.0   69990  ...  Windows 10 Home      2 GB Graphics) 7490 Thin and Li...
# 15     4.0   37379  ...  Windows 10 Home       Vostro 3401 Thin and Light Laptop
#
# [4 rows x 7 columns]

# %%
laptop_df.loc[(laptop_df['rating']>=3.5) & (laptop_df['price'].between(30000,40000))]
# Out:
#     rating  price  ...           System                              Other_Info
# 7      3.8  34990  ...  Windows 10 Home   X515JA-BR381T Thin and Light Lapto...
# 10     4.2  38499  ...  Windows 10 Home      15s-GR0011AU Thin and Light Laptop
# 13     4.3  39990  ...  Windows 10 Home           15IML05 Thin and Light Laptop
# 14     4.2  36057  ...  Windows 10 Home       Vostro 3401 Thin and Light Laptop
# 15     4.0  37379  ...  Windows 10 Home       Vostro 3401 Thin and Light Laptop
# 20     4.2  39990  ...  Windows 10 Home         14 IML 05 Thin and Light Laptop
#
# [6 rows x 7 columns]

# %% [markdown]
# ---------
#
# ### Visualización de los datos

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# Realizaremos una gráfica de barras de precio vs rating

# %%
fig, ax = plt.subplots(figsize = (20, 10))
sns.barplot(x="price",y="rating",data=laptop_df,ax=ax).set(title="Precio vs Calificación")
# Out:
# [Text(0.5, 1.0, 'Precio vs Calificación')]

# %%
fig, ax1 = plt.subplots(figsize = (20, 10))
sns.barplot(y="price",x="rating",data=laptop_df,ax=ax1).set(title="Calificación vs Precio")
# Out:
# [Text(0.5, 1.0, 'Calificación vs Precio')]

# %% [markdown]
# Podemos concluir a partir de aquí que los productos con precios más altos tienen calificaciones más altas hasta cierto punto.

# %%
sns.boxplot(x='price',data=laptop_df).set(title="Box plot")
# Out:
# [Text(0.5, 1.0, 'Box plot')]

# %% [markdown]
# ## ¿Les ha salido algún discordante visual a ustedes?

# %%
laptop_df.loc[(laptop_df['rating'] == 0.0) | (laptop_df['System'] != 'Windows 10 Home') & (laptop_df['System'] != 'Windows 10') | (laptop_df['Other_Info'] == 'NaN')]
# Out:
#     rating  ...                                         Other_Info
# 0      0.0  ...                     XPS 9300 Thin and Light Laptop
# 9      4.4  ...  Windows 10 Home) 14s-dk0501AU Thin and Light L...
# 11     0.0  ...                 2 GB Graphics) 7490 Thin and Li...
# 18     4.6  ...                   Windows 10 Home/6 GB Graphics...
#
# [4 rows x 7 columns]

# %% [markdown]
# ### ¿Para ustedes, cuáles fueron las computadoras más caras?

# %%
laptop_df.sort_values('price',ascending=False).head(5)
# Out:
#     rating  ...                                    Other_Info
# 1      4.6  ...  8 GB Graphics/NVIDIA GeForce RTX 2080 wit...
# 0      0.0  ...                XPS 9300 Thin and Light Laptop
# 18     4.6  ...              Windows 10 Home/6 GB Graphics...
# 22     4.6  ...             6 GB Graphics/NVIDIA GeForce G...
# 11     0.0  ...            2 GB Graphics) 7490 Thin and Li...
#
# [5 rows x 7 columns]

# %% [markdown]
# ----
# ----
# ----
#
# <h1><center>Monte Carlo</center><h1>
#
# ### ¿Por qué la casa siempre gana?
#
# ¿Cómo ganan dinero los casinos? El truco es sencillo: "Cuanto más juegas, más ganan". Echemos un vistazo a cómo funciona esto con un ejemplo simple de simulación de Monte Carlo.
#
# ----
#
# Considere un juego imaginario en el que un jugador tiene que elegir una ficha de una bolsa de fichas.
#
# Reglas:
#  * Hay fichas que contienen números que van del 1 al 100 en una bolsa.
#  * Los usuarios pueden apostar en fichas pares o impares.
#  * En este juego, el 10 y el 11 son números especiales. Si apostamos a pares, entonces 10 se contará como un número impar, y si apostamos a las probabilidades, entonces 11 se contará como un número par.
#  * Si apostamos a números pares y obtenemos 10, perdemos.
#  * Si apostamos a números impares y obtenemos 11, perdemos.

# %% [markdown]
# Si apostamos por las probabilidades, la probabilidad de que ganemos es de 49/100.
#
# ---
#
# La probabilidad de que la casa gane es de 51/100.
#
# ---

# %% [markdown]
# ### Importamos librerías

# %%
import random
import matplotlib.pyplot as plt

# %% [markdown]
# ### Creación de las apuestas del jugador

# %%
#Player bet
choice = input("Deseas apostar a pares o impares? \n")

#Pares
if choice == "Par":
    def pickNote():
        note = random.randint(1,100)
        if note % 2 !=0 or note==10:
            return False
        else:
            return True
#Impares
elif choice == "Odd":
    def pickNote():
        note = random.randint(1,100)
        if note % 2 ==0 or note==11:
            return False
        else:
            return True
# Out:
# Deseas apostar a pares o impares?
# Par

# %% [markdown]
# ### Función principal

# %%
def play(total_money, bet_money, total_plays):
    num_plays=[]
    money=[]
    num_plays.append(0)
    money.append(total_money)
    play = 1
    
    for play in range(total_plays):
        if pickNote():
            total_money = total_money + bet_money
            num_plays.append(play)
            money.append(total_money)
        else:
            total_money = total_money - bet_money
            num_plays.append(play)
            money.append(total_money)
    
    plt.ylabel("Dinero en $")
    plt.xlabel("Numero de apuestas")
    plt.plot(num_plays,money)
    
    final_funds.append(money[-1])
    return (final_funds)

# %% [markdown]
# ### Resultado final

# %%
final_funds = []
for i in range(10):
    ending_fund = play(10000, 100, 50)
    
print(ending_fund)
print(sum(ending_fund))

print("El jugador empezó con $10,000")
print("El jugador se fue con $", str(sum(ending_fund)/len(ending_fund)))
# Out:
# [10600, 9600, 9000, 10600, 9800, 8600, 9200, 10600, 10600, 9600]
# 98200
# El jugador empezó con $10,000
# El jugador se fue con $ 9820.0

# %% [markdown]
# ## Ahora, para un total de apuestas de 5, 10 y 1000....

# %%
final_funds = []
for i in range(10):
    ending_fund = play(10000, 100, 5)
    
print(ending_fund)
print(sum(ending_fund))

print("El jugador empezó con $10,000")
print("El jugador se fue con $", str(sum(ending_fund)/len(ending_fund)))
# Out:
# [10100, 9500, 9700, 9900, 10300, 9900, 10300, 10500, 9900, 9900]
# 100000
# El jugador empezó con $10,000
# El jugador se fue con $ 10000.0

# %%
final_funds = []
for i in range(10):
    ending_fund = play(10000, 100, 10)
    
print(ending_fund)
print(sum(ending_fund))

print("El jugador empezó con $10,000")
print("El jugador se fue con $", str(sum(ending_fund)/len(ending_fund)))
# Out:
# [9600, 10000, 9800, 9600, 10000, 9400, 10000, 10000, 9600, 9800]
# 97800
# El jugador empezó con $10,000
# El jugador se fue con $ 9780.0

# %%
final_funds = []
for i in range(10):
    ending_fund = play(10000, 100, 1000)
    
print(ending_fund)
print(sum(ending_fund))

print("El jugador empezó con $10,000")
print("El jugador se fue con $", str(sum(ending_fund)/len(ending_fund)))
# Out:
# [8600, 9000, 4600, 11000, 7600, 9600, 6400, 10000, 8200, 3400]
# 78400
# El jugador empezó con $10,000
# El jugador se fue con $ 7840.0

# %% [markdown]
# ### Ahora para mil iteraciones

# %%
final_funds = []
for i in range(1000):
    ending_fund = play(10000, 100, 5)
    
print(ending_fund)
print(sum(ending_fund))

print("El jugador empezó con $10,000")
print("El jugador se fue con $", str(sum(ending_fund)/len(ending_fund)))
# Out:
# [9900, 9900, 9900, 9900, 10300, 9700, 9900, 9700, 9900, 9700, 9700, 10100, 10100, 9700, 10100, 9700, 9900, 9700, 10100, 10100, 9900, 9500, 9900, 9700, 9700, 10100, 10100, 9900, 9900, 9900, 9700, 9700, 9900, 9900, 9700, 10500, 10100, 10300, 10300, 10100, 10300, 10100, 9900, 9900, 10300, 10300, 10500, 10300, 10100, 9900, 9700, 9900, 9500, 10100, 10300, 10300, 9700, 10300, 9900, 9900, 9700, 9900, 10100, 9900, 9700, 9700, 10100, 10300, 10100, 10100, 9700, 9700, 9700, 9700, 10100, 9900, 10100, 9700, 10100, 10100, 9900, 10100, 10100, 9700, 10100, 9900, 9900, 9500, 10100, 9500, 10300, 10100, 9900, 10100, 10300, 9500, 10100, 10100, 9700, 9900, 10500, 10100, 10100, 9900, 10100, 9700, 10100, 9900, 9900, 10100, 9700, 9900, 9700, 9900, 9700, 9700, 9700, 9900, 10100, 9900, 10500, 9700, 10300, 10100, 9700, 9
# %%
final_funds = []
for i in range(1000):
    ending_fund = play(10000, 100, 1000)
    
print(ending_fund)
print(sum(ending_fund))

print("El jugador empezó con $10,000")
print("El jugador se fue con $", str(sum(ending_fund)/len(ending_fund)))
# Out:
# [1800, 7000, 8200, 14800, 8200, 1600, 9000, 6800, 2000, 9800, 9200, 13800, 6200, 4000, 5800, 13400, 9400, 10600, 6400, 5600, 6400, 14200, 1600, 5800, 12200, 13000, 6800, 9000, 10800, 5400, 10800, 5600, 8400, 8600, 5000, 7200, 6800, 8000, 3800, 12800, 5000, 6800, 9000, 8000, 5000, 6400, 11000, 2800, 5400, 7600, 12400, 10000, 8000, 5800, 8800, 10000, 9400, 6400, 9400, 13000, 6600, 4600, 10200, 8200, 6200, 11000, 11200, 11400, 6600, 9800, 10400, 6600, 6800, 13600, 13000, 12200, 10000, 2200, 6000, 12000, 6600, 9600, 7200, 9400, 4600, 6000, 6800, 12800, 11800, 7400, 7800, 9000, 6600, 10200, 8600, 8000, 5400, 10800, 12000, 8800, 9800, 3400, 6600, 5000, 3800, 4600, 9000, 5600, 9800, 8800, 6000, 6600, 7800, 5400, 6600, 14000, 9200, 7400, 6000, 7600, 12400, 5600, 6800, 6000, 10800, 7600, 6200, 8600, 7600, 8600, 13000, 12400, 6000, 6200, 16800, 7600, 12000, 9800, 3000, 8600, 11600, 5400, 7800, 6800, 14400, 8800, 9600, 9400, 5400, 2600, 1200, 8800, 9600, 8400, 14000, 6200, 11400, 9200, 8200, 12800, 6400, 9600, 9400, 9400, 11000, 10600, 7800, 7400, 7800, 4400, 0, 10000, 10400, 15200, 6800, 1600, 6200, 8000, 12200, 9000, 4600, 10200, 10600, 10200, -200, 8200, 10200, 9800, 8200, 6400, 9200, 4200, 7000, 13000, 9800, 6800, 7800, 1000, 5400, 6600, 9800, 7800, 12800, 7000, 3600, 10800, 5400, 5400, 8800, 9200, 8600, 13400, 7400, 2800, 7200, 7000, 8600, 6400, 3800, 11600, 5400, 10800, 12000, 1600, 5800, 14200, 11000, 8000, 7800, 9600, 8400, 6800, 7400, 4400, 8400, 9400, 7400, 10800, 6800, 4800, 8200, 5000, 9400, -1400, 5000, 9400, 11600, 11600, 6200, 6600, 7800, 4600, 11200, 4800, 10800, 11800, 8000, 9800, 11000, 7800, 4400, 6200, 7400, 12000, 7800, 12400, 8200, 7600, 9200, 10000, 7800, 4600, 8200, 11400, 4600, 5600, 5400, 11200, -800, 8200, 5800, 3200, 11600, 8000, 1800, 5800, 12200, 10200, 2800, 4400, 8600, 9200, 4200, 10000, 6800, 4800, 5800, -1000, 16200, 7200, 6200, 9400, 9800, 3600, 6600, 5800, 9400, 6600, 10200, 5600, 4800, 12000, 8000, 8200, 7200, 12200, 5800, 4200, 600, 8400, 10000, 6800, 4800, 5200, 9600, 8200, 11000, 12600, 9800, 8600, 9800, 9600, 9000, 9600, 5400, 5800, 11800, 5600, 10400, 6400, 9000, 8000, 4000, 5200, 10600, 8800, 8000, 7200, 7000, 5800, 9400, 9000, 13200, 6400, 8200, 6800, 9800, 10200, 7200, 11600, 9600, 7400, 9400, 4600, 14000, 8000, 12600, 5000, 10000, 7200, 9000, 8400, 11200, 12600, 4200, 7600, 11400, 4200, 5600, 7200, 4800, 6600, 6200, 7200, 5000, 7000, 8600, 5600, 9200, 4800, 7200, 11000, 9600, 6800, 9400, 8000, 12600, 9200, 4600, 7400, 4400, 8200, 4600, 4200, 3600, 7800, 7400, 10400, 6000, 9600, 8800, 5000, 11000, 13000, 13000, 1600, 10400, 14000, 6000, 13000, 10000, 4800, 7600, 12200, 10200, 12000, 5600, 9400, 12200, 8400, 9600, 9400, 11800, 15000, 8400, 3200, 10400, 2600, 5800, 10600, 2400, 6400, 8000, 5400, 8200, 5200, 6200, 8600, 2400, 7600, 6800, 8600, 3200, 6400, 6800, 9600, 3400, 4200, 10400, 9600, 11600, 6600, 5600, 6800, 5400, 3600, 400, 6600, 9000, 7200, 3400, 11600, 2000, 2600, 6600, 7200, 7800, 8200, 10200, 6800, 7800, 5200, 11400, 10600, 6800, 10400, 5600, 9600, 4400, 2800, 8800, 7400, 6600, 7600, 8000, 9200, 10800, 5200, 9600, 7000, 2800, 8600, 3000, 8800, 14400, 9800, 10800, 7600, 9400, 9000, 13200, 8600, 7400, 4800, 11600, 11800, 7200, 8800, 9800, 9200, 8400, 10200, 7200, 11400, 12000, 9000, 5800, 3400, 7400, 5000, 4400, 10600, 8800, 11800, 7400, 1800, 9600, 12800, 14400, 5000, 7000, 10200, 6000, -400, 10000, 3200, 11200, 10400, 7400, 11200, 9000, 10600, 8600, 17600, 11000, 7000, 12000, 5600, 7600, 5200, 11000, 5200, 9000, 11200, 7600, 10200, 11400, 9400, 9400, 6400, 8400, 5000, 1600, 12000, 1600, 8400, 12000, 9200, 8200, 2400, 3800, 7000, 12600, 10400, 6200, 8000, 7800, 9600, 4600, 9800, 12000, 5400, 8400, 8200, 4000, 8600, 7200, 6400, 13000, 13000, 8800, 11200, 5000, 6400, 10600, 13200, 13800, 7000, 11200, 4600, 10200, 13400, 5000, 9200, 6600, 7400, 4600, 5200, 9000, 4400, 7400, 7200, 8000, 9800, 11200, 9000, 12400, 6400, 8600, 14400, 7600, 3000, 7600, 12600, 4800, 6200, 9000, 9400, 200, 7200 ...
# 8000600
# El jugador empezó con $10,000
# El jugador se fue con $ 8000.6

# %% [markdown]
# ### ¿Qué conclusiones puedes inferir a partir del ejercicio anterior?

# %%
count=0
for i in ending_fund:
  if i < 10000:
    count+=1
lose_percentage=count/len(ending_fund)*100
print("El "+str(lose_percentage)+ "% de los jugadores termianrá con perdidas")
# Out:
# El 73.6% de los jugadores termianrá con perdidas

# %% [markdown]
# ----
#
# Tenga en cuenta que estos porcentajes son para nuestro juego figurativo y pueden modificarse....
#
#
# -------
#
# Al igual que con cualquier modelo de pronóstico, la simulación solo será tan buena como las estimaciones que hagamos. Es importante recordar que la simulación de Monte Carlo solo representa probabilidades y no certeza. Sin embargo, la simulación de Monte Carlo puede ser una herramienta valiosa a la hora de pronosticar un futuro desconocido.
